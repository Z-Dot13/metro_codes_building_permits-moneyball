# %% [markdown]
# METRO CODES BUILDING PERMITS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# Reading-in the 8 files provided to us and looking at the data.

# %%
metro_code_CA = pd.read_csv('../data/Initiated Building Permits (CA Tasks) 3yr.csv')
# Out:
# C:\Users\galla\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
metro_code_CA
# Out:
#           PERMIT # CASE_TYPE                   CASE_TYPE_DESC   SUB_TYPE  \
# 0       2018023998      CARA  Building Residential - Addition  CAA01R301
# 1       2018023998      CARA  Building Residential - Addition  CAA01R301
# 2       2018023998      CARA  Building Residential - Addition  CAA01R301
# 3       2020011891      CARA  Building Residential - Addition  CAA01R301
# 4       2020011891      CARA  Building Residential - Addition  CAA01R301
# ...            ...       ...                              ...        ...
# 284615  2020070845      CARN       Building Residential - New  CAA01R301
# 284616  2020070845      CARN       Building Residential - New  CAA01R301
# 284617  2020070845      CARN       Building Residential - New  CAA01R301
# 284618  2020070845      CARN       Building Residential - New  CAA01R301
# 284619  2020070845      CARN       Building Residential - New  CAA01R301
#
#                   SUB_TYPE_DESC  CONSTRUCTION COST  Square Footage  \
# ...

# %%
metro_code_FR = pd.read_csv('../data/Initiated Building Permits (FR Tasks) 3yr.csv')

# %%
metro_code_FR
# Out:
#           PERMIT # CASE_TYPE                   CASE_TYPE_DESC   SUB_TYPE  \
# 0       2018023998      CARA  Building Residential - Addition  CAA01R301
# 1       2020011891      CARA  Building Residential - Addition  CAA01R301
# 2      T2018000041      CACA   Building Commercial - Addition   ADDITION
# 3      T2018000041      CACA   Building Commercial - Addition   ADDITION
# 4      T2018000179      CACR      Building Commercial - Rehab  CAF19A203
# ...            ...       ...                              ...        ...
# 47287   2019000434      CACH      Building Commercial - Shell  CAF20M001
# 47288   2019000434      CACH      Building Commercial - Shell  CAF20M001
# 47289   2019000434      CACH      Building Commercial - Shell  CAF20M001
# 47290   2020070844      CARN       Building Residential - New  CAA01R301
# 47291   2020070845      CARN       Building Residential - New  CAA01R301
#
#                             SUB_TYPE_DESC  CONSTRUCTION COST  Square Footage  \
# ...

# %%
metro_code_PL = pd.read_csv('../data/Initiated Building Permits (PL Tasks) 3yr.csv')

# %%
metro_code_PL
# Out:
#          PERMIT # CASE_TYPE                           CASE_TYPE_DESC  \
# 0     T2018003836      CACH              Building Commercial - Shell
# 1     T2018004586      CACT  Building Commercial - Tenant Finish Out
# 2     T2018005790      CACR              Building Commercial - Rehab
# 3     T2018006734      CACR              Building Commercial - Rehab
# 4     T2018010473      CACR              Building Commercial - Rehab
# ...           ...       ...                                      ...
# 6001   2019000434      CACH              Building Commercial - Shell
# 6002   2020070844      CARN               Building Residential - New
# 6003   2020070844      CARN               Building Residential - New
# 6004   2020070845      CARN               Building Residential - New
# 6005   2020070845      CARN               Building Residential - New
#
#        SUB_TYPE                          SUB_TYPE_DESC  CONSTRUCTION COST  \
# ...

# %%
metro_code_PW = pd.read_csv('../data/Initiated Building Permits (PW Tasks) 3yr.csv')

# %%
metro_code_PW
# Out:
#           PERMIT # CASE_TYPE                   CASE_TYPE_DESC   SUB_TYPE  \
# 0       2020011891      CARA  Building Residential - Addition  CAA01R301
# 1      T2018000179      CACR      Building Commercial - Rehab  CAF19A203
# 2      T2018000179      CACR      Building Commercial - Rehab  CAF19A203
# 3      T2018000649      CARN       Building Residential - New  CAA01R301
# 4      T2018000649      CARN       Building Residential - New  CAA01R301
# ...            ...       ...                              ...        ...
# 48232   2020070844      CARN       Building Residential - New  CAA01R301
# 48233   2020070844      CARN       Building Residential - New  CAA01R301
# 48234   2020070845      CARN       Building Residential - New  CAA01R301
# 48235   2020070845      CARN       Building Residential - New  CAA01R301
# 48236   2020070845      CARN       Building Residential - New  CAA01R301
#
#                    SUB_TYPE_DESC  CONSTRUCTION COST  Square Footage  \
# ...

# %%
metro_code_SW = pd.read_csv('../data/Initiated Building Permits (SW Tasks) 3yr.csv')

# %%
metro_code_SW
# Out:
#           PERMIT # CASE_TYPE                   CASE_TYPE_DESC   SUB_TYPE  \
# 0       2020011891      CARA  Building Residential - Addition  CAA01R301
# 1       2020011891      CARA  Building Residential - Addition  CAA01R301
# 2      T2018000041      CACA   Building Commercial - Addition   ADDITION
# 3      T2018000041      CACA   Building Commercial - Addition   ADDITION
# 4      T2018000649      CARN       Building Residential - New  CAA01R301
# ...            ...       ...                              ...        ...
# 46097   2020068782      CARN       Building Residential - New  CAA14U009
# 46098   2020070844      CARN       Building Residential - New  CAA01R301
# 46099   2020070844      CARN       Building Residential - New  CAA01R301
# 46100   2020070845      CARN       Building Residential - New  CAA01R301
# 46101   2020070845      CARN       Building Residential - New  CAA01R301
#
#                      SUB_TYPE_DESC  CONSTRUCTION COST  Square Footage  \
# ...

# %%
metro_code_WS = pd.read_csv('../data/Initiated Building Permits (WS Tasks) 3yr.csv')
# Out:
# C:\Users\galla\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
metro_code_WS
# Out:
#            PERMIT # CASE_TYPE                  CASE_TYPE_DESC   SUB_TYPE  \
# 0       T2018000041      CACA  Building Commercial - Addition   ADDITION
# 1       T2018000041      CACA  Building Commercial - Addition   ADDITION
# 2       T2018000041      CACA  Building Commercial - Addition   ADDITION
# 3       T2018000041      CACA  Building Commercial - Addition   ADDITION
# 4       T2018000041      CACA  Building Commercial - Addition   ADDITION
# ...             ...       ...                             ...        ...
# 103424   2020070844      CARN      Building Residential - New  CAA01R301
# 103425   2020070845      CARN      Building Residential - New  CAA01R301
# 103426   2020070845      CARN      Building Residential - New  CAA01R301
# 103427   2020070845      CARN      Building Residential - New  CAA01R301
# 103428   2020070845      CARN      Building Residential - New  CAA01R301
#
#                   SUB_TYPE_DESC  CONSTRUCTION COST  Square Footage  \
# ...

# %%
metro_code_U_O = pd.read_csv('../data/Initiated Building Permits 3yr (Temp-Final U_O).csv')

# %%
metro_code_U_O
# Out:
#          PERMIT # CASE_TYPE                           CASE_TYPE_DESC  \
# 0      2018000034      CARR             Building Residential - Rehab
# 1      2018000187      CARR             Building Residential - Rehab
# 2      2018045480      CACN                Building Commercial - New
# 3      2018057638      CACR              Building Commercial - Rehab
# 4      2018059485      CACR              Building Commercial - Rehab
# ...           ...       ...                                      ...
# 14155  2019078601      CARN               Building Residential - New
# 14156  2019078821      CARN               Building Residential - New
# 14157  2019079228      CARN               Building Residential - New
# 14158  2020022071      CACT  Building Commercial - Tenant Finish Out
# 14159  2020079281      CARA          Building Residential - Addition
#
#         SUB_TYPE                          SUB_TYPE_DESC STATUS_CODE  \
# 0      CAA01R301                Single Family Residence        DONE
# ...

# %%
metro_code = pd.read_csv('../data/Initiated Building Permits 3yr.csv')

# %%
metro_code
# Out:
#           PERMIT # CASE_TYPE                   CASE_TYPE_DESC   SUB_TYPE  \
# 0       2018023998      CARA  Building Residential - Addition  CAA01R301
# 1       2020011891      CARA  Building Residential - Addition  CAA01R301
# 2      D2019001438      CARR     Building Residential - Rehab  CAA01R301
# 3      D2019005512      CARA  Building Residential - Addition  CAA02R302
# 4      D2019051121      CARR     Building Residential - Rehab  CAA01R301
# ...            ...       ...                              ...        ...
# 31726   2020061840      CACN        Building Commercial - New  CAF20M001
# 31727   2019000434      CACH      Building Commercial - Shell  CAF20M001
# 31728   2020068782      CARN       Building Residential - New  CAA14U009
# 31729   2020070844      CARN       Building Residential - New  CAA01R301
# 31730   2020070845      CARN       Building Residential - New  CAA01R301
#
#                             SUB_TYPE_DESC  CONSTRUCTION COST  Square Footage  \
# ...
